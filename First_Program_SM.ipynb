# %% [markdown]
# <a href="https://colab.research.google.com/github/nawrin1/First_Program_SM/blob/main/First_Program_SM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello there! I am really excited to start this new journey")
# Out:
# Hello there! I am really excited to start this new journey

# %%
print("I hope that the journey will be smooth and exciting")
# Out:
# I hope that the journey will be smooth and exciting
